# %%
# %%html
# uv run python -m http.server 8000
# <iframe src="http://localhost:8000/rearrange_problem.html" width="400" height="300"></iframe>
# Out:
# <iframe src="http://localhost:8000/rearrange_problem.html" width="400" height="300"></iframe>
